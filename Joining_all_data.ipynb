# %% [markdown]
# # Joining All Data

# %%
import pandas as pd

# %%
df_drought_usa = pd.read_csv('Data/df_drought_usa.csv')

# %%
df_county_presidential_agg = pd.read_csv('Data/df_county_presidential_agg.csv')

# %%
df_burned_area_index = pd.read_csv('Data/df_burned_area_index.csv', sep=';')

# %%
df_drought_usa.head(3)
# Out:
#    state_fips  county_fips  value        date
# 0           2         2013      9  2000-04-01
# 1           2         2013      9  2000-11-01
# 2           2         2013      9  2000-01-18

# %%
df_county_presidential_agg.head(3)
# Out:
#      state   county  year_short  candidate_votes       party  county_fips  \
# 0  ALABAMA  AUTAUGA        2000            11993  REPUBLICAN         1001
# 1  ALABAMA  AUTAUGA        2004            15196  REPUBLICAN         1001
# 2  ALABAMA  AUTAUGA        2008            17403  REPUBLICAN         1001
#
#                             year
# 0  1970-01-01 00:00:00.000002000
# 1  1970-01-01 00:00:00.000002004
# 2  1970-01-01 00:00:00.000002008

# %%
df_county_presidential_agg.rename(columns={'year':'year_long'}, inplace=True)

# %%
df_county_presidential_agg.rename(columns={'year_short':'year'}, inplace=True)

# %%
df_county_presidential_agg.head(3)
# Out:
#      state   county  year  candidate_votes       party  county_fips  \
# 0  ALABAMA  AUTAUGA  2000            11993  REPUBLICAN         1001
# 1  ALABAMA  AUTAUGA  2004            15196  REPUBLICAN         1001
# 2  ALABAMA  AUTAUGA  2008            17403  REPUBLICAN         1001
#
#                        year_long
# 0  1970-01-01 00:00:00.000002000
# 1  1970-01-01 00:00:00.000002004
# 2  1970-01-01 00:00:00.000002008

# %%
df_burned_area_index.head(3)
# Out:
#      State  Hectares  Year  Month GID_0        Country    GID_1  \
# 0  Alabama  13576700  2002      1   USA  United States  USA.1_1
# 1  Alabama  13576700  2002      2   USA  United States  USA.1_1
# 2  Alabama  13576700  2002      3   USA  United States  USA.1_1
#
#    Cropland_BA_hectares  Forest_BA_hectares  Grass_and_Shrubland_BA_hectares  \
# 0                   107                 193                               21
# 1                    43                2426                               43
# 2                    43                3177                                0
#
#    ...  Settlement_BA_hectares  Other_BA_hectares  combined_BA  \
# 0  ...                       0                  0          321
# 1  ...                       0                  0         2533
# 2  ...                       0                  0         3241
#
#    burned_area_state_index  Burned_Cropland_index  Burned_Forest_index  \
# ...

# %%
df_burned_area_index.rename(columns={'State':'state'}, inplace=True)

# %%
df_burned_area_index['state'] = df_burned_area_index['state'].str.upper()

# %%
df_burned_area_index.rename(columns={'Year':'year'}, inplace=True)

# %%
df_burned_area_index.head(3)
# Out:
#      state  Hectares  year  Month GID_0        Country    GID_1  \
# 0  ALABAMA  13576700  2002      1   USA  United States  USA.1_1
# 1  ALABAMA  13576700  2002      2   USA  United States  USA.1_1
# 2  ALABAMA  13576700  2002      3   USA  United States  USA.1_1
#
#    Cropland_BA_hectares  Forest_BA_hectares  Grass_and_Shrubland_BA_hectares  \
# 0                   107                 193                               21
# 1                    43                2426                               43
# 2                    43                3177                                0
#
#    ...  Settlement_BA_hectares  Other_BA_hectares  combined_BA  \
# 0  ...                       0                  0          321
# 1  ...                       0                  0         2533
# 2  ...                       0                  0         3241
#
#    burned_area_state_index  Burned_Cropland_index  Burned_Forest_index  \
# ...

# %%
df_burned_area_index.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11016 entries, 0 to 11015
# Data columns (total 21 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   state                             11016 non-null  object
#  1   Hectares                          11016 non-null  int64
#  2   year                              11016 non-null  int64
#  3   Month                             11016 non-null  int64
#  4   GID_0                             11016 non-null  object
#  5   Country                           11016 non-null  object
#  6   GID_1                             11016 non-null  object
#  7   Cropland_BA_hectares              11016 non-null  int64
#  8   Forest_BA_hectares                11016 non-null  int64
#  9   Grass_and_Shrubland_BA_hectares   11016 non-null  int64
#  10  Wetlands_BA_hectares              11016 non-null  int64
# ...

# %%
three_tables = pd.merge(pd.merge(df_burned_area_index,df_county_presidential_agg,on='state'),df_drought_usa,on='county_fips')
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Input In [17], in <cell line: 1>()
# ----> 1 three_tables = pd.merge(pd.merge(df_burned_area_index,df_county_presidential_agg,on='state'),df_drought_usa,on='county_fips')
#
# File ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py:122, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      90 @Substitution("\nleft : DataFrame or named Series")
#      91 @Appender(_merge_doc, indents=0)
#      92 def merge(
#    (...)
#     105     validate: str | None = None,
#     106 ) -> DataFrame:
#     107     op = _MergeOperation(
#     108         left,
#     109         right,
#    (...)
#     120         validate=validate,
#     121     )
# --> 122     return op.get_result()
#
# ...

# %%
#all_tables = df_drought_usa.merge(df_county_presidential_agg, on='county_fips', how='left')

# %%
#all_tables.head(3)

# %%
#all_tables['year'] = all_tables['year'].fillna(0)

# %%
#all_tables['year'] = all_tables.year.astype(int)

# %%
# all_tables = all_tables.merge(df_burned_area_index, on='state', how='left')    
#all_tables = all_tables.merge(df_burned_area_index, on='year', how='left')    
# all_tables = pd.merge(all_tables, df_burned_area_index, how='left', left_on=['state'], right_on = ['state'])    
#all_tables = pd.merge(all_tables, df_burned_area_index, how='left', left_on=['state', 'year'], right_on = ['state', 'year'])

# %%
all_tables.head(3)
