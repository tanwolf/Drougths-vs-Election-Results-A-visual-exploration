# %% [markdown]
# # Cleaning Data for tableau

# %%
import pandas as pd

# %%
df_drought_usa = pd.read_csv('Data/United_States_Drought_Monitor__2000-2016.csv')

# %%
df_county_presidential = pd.read_csv("Data/countypres_2000-2020_county.csv")

# %%
df_drought_usa.head()
# Out:
#    year  month  day  statefips  countyfips  value
# 0  2000      1    4          2        2013      9
# 1  2000      1   11          2        2013      9
# 2  2000      1   18          2        2013      9
# 3  2000      1   25          2        2013      9
# 4  2000      2    1          2        2013      9

# %%
df_county_presidential.head()
# Out:
#    year    state state_po county_name  county_fips        office  \
# 0  2000  ALABAMA       AL     AUTAUGA       1001.0  US PRESIDENT
# 1  2000  ALABAMA       AL     AUTAUGA       1001.0  US PRESIDENT
# 2  2000  ALABAMA       AL     AUTAUGA       1001.0  US PRESIDENT
# 3  2000  ALABAMA       AL     AUTAUGA       1001.0  US PRESIDENT
# 4  2000  ALABAMA       AL     BALDWIN       1003.0  US PRESIDENT
#
#         candidate       party  candidatevotes  totalvotes   version   mode
# 0         AL GORE    DEMOCRAT            4942       17208  20220315  TOTAL
# 1  GEORGE W. BUSH  REPUBLICAN           11993       17208  20220315  TOTAL
# 2     RALPH NADER       GREEN             160       17208  20220315  TOTAL
# 3           OTHER       OTHER             113       17208  20220315  TOTAL
# 4         AL GORE    DEMOCRAT           13997       56480  20220315  TOTAL

# %%
df_county_presidential.head()
# Out:
#    year    state state_po county_name  county_fips        office  \
# 0  2000  ALABAMA       AL     AUTAUGA       1001.0  US PRESIDENT
# 1  2000  ALABAMA       AL     AUTAUGA       1001.0  US PRESIDENT
# 2  2000  ALABAMA       AL     AUTAUGA       1001.0  US PRESIDENT
# 3  2000  ALABAMA       AL     AUTAUGA       1001.0  US PRESIDENT
# 4  2000  ALABAMA       AL     BALDWIN       1003.0  US PRESIDENT
#
#         candidate       party  candidatevotes  totalvotes   version   mode
# 0         AL GORE    DEMOCRAT            4942       17208  20220315  TOTAL
# 1  GEORGE W. BUSH  REPUBLICAN           11993       17208  20220315  TOTAL
# 2     RALPH NADER       GREEN             160       17208  20220315  TOTAL
# 3           OTHER       OTHER             113       17208  20220315  TOTAL
# 4         AL GORE    DEMOCRAT           13997       56480  20220315  TOTAL

# %% [markdown]
# # Formatting Drought Data

# %%
# Renaming the columns 
df_drought_usa.columns = ['year', 'month', 'day', 'state_fips', 'county_fips', 'value']
df_drought_usa.head()
# Out:
#    year  month  day  state_fips  county_fips  value
# 0  2000      1    4           2         2013      9
# 1  2000      1   11           2         2013      9
# 2  2000      1   18           2         2013      9
# 3  2000      1   25           2         2013      9
# 4  2000      2    1           2         2013      9

# %%
# Add zero in front of day date if is day date consists of only on digit
df_drought_usa['day'] = df_drought_usa.day.astype(str).str.rjust(2, '0')

# %%
# Add zero in front of month datae is month date consists of only on digit
df_drought_usa['month'] = df_drought_usa.month.astype(str).str.rjust(2, '0')

# %%
# concatinate everything into a single data column
df_drought_usa['date'] = df_drought_usa.day.astype(str) + '/' + df_drought_usa.month.astype(str) + '/' + df_drought_usa.year.astype(str)

# %%
df_drought_usa.head()
# Out:
#    year month day  state_fips  county_fips  value        date
# 0  2000    01  04           2         2013      9  04/01/2000
# 1  2000    01  11           2         2013      9  11/01/2000
# 2  2000    01  18           2         2013      9  18/01/2000
# 3  2000    01  25           2         2013      9  25/01/2000
# 4  2000    02  01           2         2013      9  01/02/2000

# %%
# Drop columns year, day, month
df_drought_usa.drop(columns=['year', 'month', 'day'], inplace=True)

# %%
df_drought_usa.head()
# Out:
#    state_fips  county_fips  value        date
# 0           2         2013      9  04/01/2000
# 1           2         2013      9  11/01/2000
# 2           2         2013      9  18/01/2000
# 3           2         2013      9  25/01/2000
# 4           2         2013      9  01/02/2000

# %%
# Add 0 in front of state_fips if it is a single digit
df_drought_usa['state_fips'] = df_drought_usa.state_fips.astype(str).str.rjust(2, '0')

# %%
# county_fips: Adding a zero as a first digit when there are only 4 digits instead of 5 (convert countyfips to string)
df_drought_usa.county_fips = df_drought_usa.county_fips.astype(str).str.rjust(5, "0")
df_drought_usa.county_fips.head()
# Out:
# 0    02013
# 1    02013
# 2    02013
# 3    02013
# 4    02013
# Name: county_fips, dtype: object

# %%
df_drought_usa.head()
# Out:
#   state_fips county_fips  value        date
# 0         02       02013      9  04/01/2000
# 1         02       02013      9  11/01/2000
# 2         02       02013      9  18/01/2000
# 3         02       02013      9  25/01/2000
# 4         02       02013      9  01/02/2000

# %%
df_drought_usa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2786067 entries, 0 to 2786066
# Data columns (total 4 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   state_fips   object
#  1   county_fips  object
#  2   value        int64
#  3   date         object
# dtypes: int64(1), object(3)
# memory usage: 85.0+ MB

# %%
# Turning date to datetime
df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# Out:
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '18/01/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '25/01/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '15/02/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '22/02/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '29/02/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '14/03/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '21/03/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '28/03/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '18/04/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '25/04/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '16/05/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '23/05/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '30/05/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '13/06/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '20/06/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '27/06/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '18/07/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '25/07/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '15/08/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '22/08/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '29/08/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '19/09/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '26/09/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '17/10/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '24/10/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '31/10/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '14/11/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '21/11/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '28/11/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '19/12/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '26/12/2000' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '16/01/2001' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '23/01/2001' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '30/01/2001' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '13/02/2001' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '20/02/2001' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '27/02/2001' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '13/03/2001' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '20/03/2001' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '27/03/2001' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '17/04/2001' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '24/04/2001' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '15/05/2001' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '22/05/2001' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '29/05/2001' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '19/06/2001' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '26/06/2001' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '17/07/2001' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '24/07/2001' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '31/07/2001' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '14/08/2001' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '21/08/2001' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '28/08/2001' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '18/09/2001' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '25/09/2001' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '16/10/2001' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '23/10/2001' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '30/10/2001' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '13/11/2001' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '20/11/2001' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '27/11/2001' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '18/12/2001' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '25/12/2001' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '15/01/2002' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '22/01/2002' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '29/01/2002' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '19/02/2002' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '26/02/2002' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '19/03/2002' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '26/03/2002' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '16/04/2002' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '23/04/2002' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '30/04/2002' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '14/05/2002' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '21/05/2002' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '28/05/2002' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '18/06/2002' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '25/06/2002' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '16/07/2002' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '23/07/2002' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '30/07/2002' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '13/08/2002' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '20/08/2002' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '27/08/2002' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '17/09/2002' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '24/09/2002' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '15/10/2002' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '22/10/2002' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '29/10/2002' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '19/11/2002' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '26/11/2002' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '17/12/2002' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '24/12/2002' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '31/12/2002' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '14/01/2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '21/01/2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '28/01/2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '18/02/2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '25/02/2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '18/03/2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '25/03/2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '15/04/2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '22/04/2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '29/04/2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '13/05/2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '20/05/2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '27/05/2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '17/06/2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '24/06/2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '15/07/2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '22/07/2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '29/07/2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '19/08/2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '26/08/2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '16/09/2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '23/09/2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '30/09/2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '14/10/2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '21/10/2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '28/10/2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '18/11/2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '25/11/2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '16/12/2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '23/12/2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '30/12/2003' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '13/01/2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '20/01/2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '27/01/2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '17/02/2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '24/02/2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '16/03/2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '23/03/2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '30/03/2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '13/04/2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '20/04/2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '27/04/2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '18/05/2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '25/05/2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '15/06/2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '22/06/2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '29/06/2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '13/07/2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '20/07/2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '27/07/2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '17/08/2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '24/08/2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '31/08/2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '14/09/2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '21/09/2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '28/09/2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '19/10/2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '26/10/2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '16/11/2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '23/11/2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '30/11/2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '14/12/2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '21/12/2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '28/12/2004' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '18/01/2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '25/01/2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '15/02/2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '22/02/2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '15/03/2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '22/03/2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '29/03/2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '19/04/2005' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# ...
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '14/04/2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '21/04/2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '28/04/2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '19/05/2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '26/05/2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '16/06/2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '23/06/2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '30/06/2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '14/07/2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '21/07/2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '28/07/2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '18/08/2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '25/08/2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '15/09/2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '22/09/2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '29/09/2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '13/10/2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '20/10/2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '27/10/2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '17/11/2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '24/11/2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '15/12/2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '22/12/2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '29/12/2015' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '19/01/2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '26/01/2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '16/02/2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '23/02/2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '15/03/2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '22/03/2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '29/03/2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '19/04/2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '26/04/2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '17/05/2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '24/05/2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '31/05/2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '14/06/2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '21/06/2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '28/06/2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '19/07/2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '26/07/2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '16/08/2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '23/08/2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '30/08/2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '13/09/2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '20/09/2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '27/09/2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '18/10/2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '25/10/2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '15/11/2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '22/11/2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '29/11/2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '13/12/2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '20/12/2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_8084\597276774.py:2: UserWarning: Parsing '27/12/2016' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df_drought_usa.date = pd.to_datetime(df_drought_usa['date'], infer_datetime_format=True)

# %%
df_drought_usa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2786067 entries, 0 to 2786066
# Data columns (total 4 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   state_fips   object
#  1   county_fips  object
#  2   value        int64
#  3   date         datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 85.0+ MB

# %%
df_drought_usa.head()
# Out:
#   state_fips county_fips  value       date
# 0         02       02013      9 2000-04-01
# 1         02       02013      9 2000-11-01
# 2         02       02013      9 2000-01-18
# 3         02       02013      9 2000-01-25
# 4         02       02013      9 2000-01-02

# %%
df_drought_usa.to_csv('Data/df_drought_usa.csv', index=False, sep=',')

# %% [markdown]
# # Formatting data of the presidential election

# %%
df_county_presidential.head()
# Out:
#    year    state state_po county_name  county_fips        office  \
# 0  2000  ALABAMA       AL     AUTAUGA       1001.0  US PRESIDENT
# 1  2000  ALABAMA       AL     AUTAUGA       1001.0  US PRESIDENT
# 2  2000  ALABAMA       AL     AUTAUGA       1001.0  US PRESIDENT
# 3  2000  ALABAMA       AL     AUTAUGA       1001.0  US PRESIDENT
# 4  2000  ALABAMA       AL     BALDWIN       1003.0  US PRESIDENT
#
#         candidate       party  candidatevotes  totalvotes   version   mode
# 0         AL GORE    DEMOCRAT            4942       17208  20220315  TOTAL
# 1  GEORGE W. BUSH  REPUBLICAN           11993       17208  20220315  TOTAL
# 2     RALPH NADER       GREEN             160       17208  20220315  TOTAL
# 3           OTHER       OTHER             113       17208  20220315  TOTAL
# 4         AL GORE    DEMOCRAT           13997       56480  20220315  TOTAL

# %%
df_county_presidential.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72617 entries, 0 to 72616
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   year            72617 non-null  int64
#  1   state           72617 non-null  object
#  2   state_po        72617 non-null  object
#  3   county_name     72617 non-null  object
#  4   county_fips     72560 non-null  float64
#  5   office          72617 non-null  object
#  6   candidate       72617 non-null  object
#  7   party           72617 non-null  object
#  8   candidatevotes  72617 non-null  int64
#  9   totalvotes      72617 non-null  int64
#  10  version         72617 non-null  int64
#  11  mode            72617 non-null  object
# dtypes: float64(1), int64(4), object(7)
# memory usage: 6.6+ MB

# %%
# rename columns
df_county_presidential.columns = ['year', 'state', 'state_po', 'county', 'county_fips', 'office',
       'candidate', 'party', 'candidate_votes', 'total_votes', 'version',
       'mode']

# %%
# conversion to 'int' does not work because of NA values > Convert NA to 0
df_county_presidential['county_fips'] = df_county_presidential['county_fips'].fillna(0)

# %%
# Convert county_fips to integer
df_county_presidential.county_fips = df_county_presidential.county_fips.astype(int)

# %%
# Add zeros to count_fips
df_county_presidential.county_fips = df_county_presidential.county_fips = df_county_presidential.county_fips.astype(str).str.rjust(5, '0')

# %%
df_county_presidential.head()
# Out:
#    year    state state_po   county county_fips        office       candidate  \
# 0  2000  ALABAMA       AL  AUTAUGA       01001  US PRESIDENT         AL GORE
# 1  2000  ALABAMA       AL  AUTAUGA       01001  US PRESIDENT  GEORGE W. BUSH
# 2  2000  ALABAMA       AL  AUTAUGA       01001  US PRESIDENT     RALPH NADER
# 3  2000  ALABAMA       AL  AUTAUGA       01001  US PRESIDENT           OTHER
# 4  2000  ALABAMA       AL  BALDWIN       01003  US PRESIDENT         AL GORE
#
#         party  candidate_votes  total_votes   version   mode
# 0    DEMOCRAT             4942        17208  20220315  TOTAL
# 1  REPUBLICAN            11993        17208  20220315  TOTAL
# 2       GREEN              160        17208  20220315  TOTAL
# 3       OTHER              113        17208  20220315  TOTAL
# 4    DEMOCRAT            13997        56480  20220315  TOTAL

# %%
# county_fips: Adding a zero as a first digit when there are only 4 digits instead of 5 (convert county_fips to string)
df_county_presidential.county_fips.astype(str).str.replace('.0', '', regex=False).str.rjust(5, fillchar="0")
# Out:
# 0        01001
# 1        01001
# 2        01001
# 3        01001
# 4        01003
#          ...
# 72612    56043
# 72613    56045
# 72614    56045
# 72615    56045
# 72616    56045
# Name: county_fips, Length: 72617, dtype: object

# %%
df_county_presidential.head()
# Out:
#    year    state state_po   county county_fips        office       candidate  \
# 0  2000  ALABAMA       AL  AUTAUGA       01001  US PRESIDENT         AL GORE
# 1  2000  ALABAMA       AL  AUTAUGA       01001  US PRESIDENT  GEORGE W. BUSH
# 2  2000  ALABAMA       AL  AUTAUGA       01001  US PRESIDENT     RALPH NADER
# 3  2000  ALABAMA       AL  AUTAUGA       01001  US PRESIDENT           OTHER
# 4  2000  ALABAMA       AL  BALDWIN       01003  US PRESIDENT         AL GORE
#
#         party  candidate_votes  total_votes   version   mode
# 0    DEMOCRAT             4942        17208  20220315  TOTAL
# 1  REPUBLICAN            11993        17208  20220315  TOTAL
# 2       GREEN              160        17208  20220315  TOTAL
# 3       OTHER              113        17208  20220315  TOTAL
# 4    DEMOCRAT            13997        56480  20220315  TOTAL

# %%
# Changing year to datetime
df_county_presidential['year'] = pd.to_datetime(df_county_presidential['year'])

# %%
df_county_presidential.head()
# Out:
#                         year    state state_po   county county_fips  \
# 0 1970-01-01 00:00:00.000002  ALABAMA       AL  AUTAUGA       01001
# 1 1970-01-01 00:00:00.000002  ALABAMA       AL  AUTAUGA       01001
# 2 1970-01-01 00:00:00.000002  ALABAMA       AL  AUTAUGA       01001
# 3 1970-01-01 00:00:00.000002  ALABAMA       AL  AUTAUGA       01001
# 4 1970-01-01 00:00:00.000002  ALABAMA       AL  BALDWIN       01003
#
#          office       candidate       party  candidate_votes  total_votes  \
# 0  US PRESIDENT         AL GORE    DEMOCRAT             4942        17208
# 1  US PRESIDENT  GEORGE W. BUSH  REPUBLICAN            11993        17208
# 2  US PRESIDENT     RALPH NADER       GREEN              160        17208
# 3  US PRESIDENT           OTHER       OTHER              113        17208
# 4  US PRESIDENT         AL GORE    DEMOCRAT            13997        56480
#
#     version   mode
# 0  20220315  TOTAL
# 1  20220315  TOTAL
# 2  20220315  TOTAL
# 3  20220315  TOTAL
# 4  20220315  TOTAL

# %%
df_county_presidential.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72617 entries, 0 to 72616
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   year             72617 non-null  datetime64[ns]
#  1   state            72617 non-null  object
#  2   state_po         72617 non-null  object
#  3   county           72617 non-null  object
#  4   county_fips      72617 non-null  object
#  5   office           72617 non-null  object
#  6   candidate        72617 non-null  object
#  7   party            72617 non-null  object
#  8   candidate_votes  72617 non-null  int64
#  9   total_votes      72617 non-null  int64
#  10  version          72617 non-null  int64
#  11  mode             72617 non-null  object
# dtypes: datetime64[ns](1), int64(3), object(8)
# memory usage: 6.6+ MB

# %%
df_county_presidential.to_csv('Data/df_county_presidential.csv', sep = ',', index =False)

# %% [markdown]
# # Formatting Fips Codes

# %%
# example data of how to format Fips Codes in tableau
df_fips_5 = pd.read_csv("Data/NY FIPS 5 (FIPS Codes)_Migrated Data.csv", sep =';')

# %%
df_fips_5.info()

# %%
df_fips_5.head(3)
