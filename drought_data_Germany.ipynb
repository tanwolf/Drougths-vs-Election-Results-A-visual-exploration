# %% [markdown]
# # Draught Data Germany

# %% [markdown]
# I downloaded data from the Helmholtz institutes draught monitor for Germany.
# https://www.ufz.de/index.php?de=37937
#
# This data is availabel in .nc format: In order to import it into PowerBI it has to be converted into .csv format
#
# Source: UFZ-Dürremonitor/ Helmholtz-Zentrum für Umweltforschung
#
# Good tutorial about how to visualize .nc data:
# https://youtu.be/wXCYtPlT-kg

# %%
# prepare for plotting in python
# !pip install netCDF4
# Out:
# Requirement already satisfied: netCDF4 in c:\users\tanja\anaconda3\lib\site-packages (1.6.0)
# Requirement already satisfied: numpy>=1.9 in c:\users\tanja\anaconda3\lib\site-packages (from netCDF4) (1.21.5)
# Requirement already satisfied: cftime in c:\users\tanja\anaconda3\lib\site-packages (from netCDF4) (1.6.1)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\tanja\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\tanja\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\tanja\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\tanja\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\tanja\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\tanja\anaconda3\lib\site-packages)

# %%
pip install --upgrade matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\tanja\anaconda3\lib\site-packages (3.5.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\tanja\anaconda3\lib\site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\tanja\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\tanja\anaconda3\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\tanja\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\tanja\anaconda3\lib\site-packages (from matplotlib) (1.21.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\tanja\anaconda3\lib\site-packages (from matplotlib) (1.4.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\tanja\anaconda3\lib\site-packages (from matplotlib) (9.0.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\tanja\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\tanja\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\tanja\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\tanja\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\tanja\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\tanja\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\tanja\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\tanja\anaconda3\lib\site-packages)

# %%
# import python librabries
from netCDF4 import Dataset
import numpy as np
import matplotlib.pyplot as plt
import mpl_toolkits
#from mpl_toolkits import Basemap # Warum funktioniert es nicht?

# %% [markdown]
# **Open the dataset in reading mode 'r'**

# %%
nc_file = '253177_Duerremagnitude_Gesamtboden_1952-2020_Apr-Okt.nc'
data = Dataset(nc_file)#, mode='r')
data
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     affiliation: UFZ - Helmholtz Zentrum fuer Umweltforschung
#     NCO: netCDF Operators version 4.9.3 (Homepage = http://nco.sf.net, Code = http://github.com/nco/nco)
#     contact: klima@ufz.de
#     dimensions(sizes): time(69), bnds(2), easting(175), northing(225)
#     variables(dimensions): float64 time(time), float64 time_bnds(time, bnds), int32 easting(easting), int32 northing(northing), float32 droughtmagnitude(time, northing, easting)
#     groups:

# %% [markdown]
# **Convert netCDF4 data into a pandas dataframe**

# %%
# convert draught data into pandas dataframe:

import xarray as xr

ds = xr.open_dataset('253177_Duerremagnitude_Gesamtboden_1952-2020_Apr-Okt.nc')
df = ds.to_dataframe()
df.head(100)
# Out:
#                                            time_bnds  droughtmagnitude
# time                bnds easting northing
# 1952-07-16 12:00:00 0    4040000 5222000  1952-04-01               NaN
#                                  5226000  1952-04-01               NaN
#                                  5230000  1952-04-01               NaN
#                                  5234000  1952-04-01               NaN
#                                  5238000  1952-04-01               NaN
# ...                                              ...               ...
#                                  5602000  1952-04-01               NaN
#                                  5606000  1952-04-01               NaN
#                                  5610000  1952-04-01               NaN
#                                  5614000  1952-04-01               NaN
#                                  5618000  1952-04-01               NaN
#
# [100 rows x 2 columns]

# %%
# reset the index of th enew dataframe
df.reset_index(inplace=True)

# %%
df
# Out:
#                        time  bnds  easting  northing  time_bnds  \
# 0       1952-07-16 12:00:00     0  4040000   5222000 1952-04-01
# 1       1952-07-16 12:00:00     0  4040000   5226000 1952-04-01
# 2       1952-07-16 12:00:00     0  4040000   5230000 1952-04-01
# 3       1952-07-16 12:00:00     0  4040000   5234000 1952-04-01
# 4       1952-07-16 12:00:00     0  4040000   5238000 1952-04-01
# ...                     ...   ...      ...       ...        ...
# 5433745 2020-07-16 12:00:00     1  4736000   6102000 2020-10-31
# 5433746 2020-07-16 12:00:00     1  4736000   6106000 2020-10-31
# 5433747 2020-07-16 12:00:00     1  4736000   6110000 2020-10-31
# 5433748 2020-07-16 12:00:00     1  4736000   6114000 2020-10-31
# 5433749 2020-07-16 12:00:00     1  4736000   6118000 2020-10-31
#
#          droughtmagnitude
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# 5433745               NaN
# 5433746               NaN
# 5433747               NaN
# 5433748               NaN
# 5433749               NaN
#
# [5433750 rows x 6 columns]

# %%
# Add two new numerical columns to dataframe:
# https://sparkbyexamples.com/pandas/pandas-add-an-empty-column-to-dataframe/
df['latitude']= np.nan
df['longitude']= np.nan
df
# Out:
#                        time  bnds  easting  northing  time_bnds  \
# 0       1952-07-16 12:00:00     0  4040000   5222000 1952-04-01
# 1       1952-07-16 12:00:00     0  4040000   5226000 1952-04-01
# 2       1952-07-16 12:00:00     0  4040000   5230000 1952-04-01
# 3       1952-07-16 12:00:00     0  4040000   5234000 1952-04-01
# 4       1952-07-16 12:00:00     0  4040000   5238000 1952-04-01
# ...                     ...   ...      ...       ...        ...
# 5433745 2020-07-16 12:00:00     1  4736000   6102000 2020-10-31
# 5433746 2020-07-16 12:00:00     1  4736000   6106000 2020-10-31
# 5433747 2020-07-16 12:00:00     1  4736000   6110000 2020-10-31
# 5433748 2020-07-16 12:00:00     1  4736000   6114000 2020-10-31
# 5433749 2020-07-16 12:00:00     1  4736000   6118000 2020-10-31
#
#          droughtmagnitude  latitude  longitude
# 0                     NaN       NaN        NaN
# 1                     NaN       NaN        NaN
# 2                     NaN       NaN        NaN
# 3                     NaN       NaN        NaN
# 4                     NaN       NaN        NaN
# ...                   ...       ...        ...
# 5433745               NaN       NaN        NaN
# 5433746               NaN       NaN        NaN
# 5433747               NaN       NaN        NaN
# 5433748               NaN       NaN        NaN
# 5433749               NaN       NaN        NaN
#
# [5433750 rows x 8 columns]

# %%
# check if new columns are in float format
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5433750 entries, 0 to 5433749
# Data columns (total 8 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   time              datetime64[ns]
#  1   bnds              int64
#  2   easting           int64
#  3   northing          int64
#  4   time_bnds         datetime64[ns]
#  5   droughtmagnitude  float32
#  6   latitude          float64
#  7   longitude         float64
# dtypes: datetime64[ns](2), float32(1), float64(2), int64(3)
# memory usage: 310.9 MB

# %%
# Translate easting and northing into latitude and longitude
pip install pyproj
# Out:
#   Input In [95]
#     pip install pyproj
#         ^
# SyntaxError: invalid syntax

# %%
# convert Gauß to lat/ lon: https://gis.stackexchange.com/questions/78838/converting-projected-coordinates-to-lat-lon-using-python
from pyproj import Proj, transform

inProj = Proj(init='epsg:31468')
outProj = Proj(init='epsg:4326')
x1,y1 = 4040000,5222000 # easting, northing
x2,y2 = transform(inProj,outProj,x1,y1)
print(x2,y2)
# Out:
# 5.952251378874303 46.976737330247346
# C:\Users\Tanja\anaconda3\lib\site-packages\pyproj\crs\crs.py:130: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# C:\Users\Tanja\anaconda3\lib\site-packages\pyproj\crs\crs.py:130: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_1980\829373148.py:7: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x2,y2 = transform(inProj,outProj,x1,y1)

# %%
# Try transformation on one row
inProj = Proj(init='epsg:31468')
outProj = Proj(init='epsg:4326')
x1,y1 = 4040000,5222000 # easting, northing
x2,y2 = transform(inProj,outProj,x1,y1) # latitude, longitude?
print(x2)
print(y2)

# %%
inProj = Proj(init='epsg:31468')
outProj = Proj(init='epsg:4326')
x1,y1 = 4040000,5222000 # easting, northing
x2,y2 = transform(inProj,outProj,df['easting'].values,df['northing'].values) # latitude, longitude
print(x2)
print(y2)
# Out:
# C:\Users\Tanja\anaconda3\lib\site-packages\pyproj\crs\crs.py:130: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# C:\Users\Tanja\anaconda3\lib\site-packages\pyproj\crs\crs.py:130: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_1980\3851100150.py:4: DeprecationWarning: This function is deprecated. See: https://pyproj4.github.io/pyproj/stable/gotchas.html#upgrading-to-pyproj-2-from-pyproj-1
#   x2,y2 = transform(inProj,outProj,df['easting'].values,df['northing'].values) # latitude, longitude
# [ 5.95225138  5.94819867  5.94413818 ... 15.69289834 15.69620818
#  15.69952539]
# [46.97673733 47.01251732 47.04829681 ... 55.06264141 55.09849753
#  55.13435331]

# %%
# Apply transformation to all the rows in latitude and longitude
df['latitude']=x2
df['longitude']=y2

# %%
df
# Out:
#                        time  bnds  easting  northing  time_bnds  \
# 0       1952-07-16 12:00:00     0  4040000   5222000 1952-04-01
# 1       1952-07-16 12:00:00     0  4040000   5226000 1952-04-01
# 2       1952-07-16 12:00:00     0  4040000   5230000 1952-04-01
# 3       1952-07-16 12:00:00     0  4040000   5234000 1952-04-01
# 4       1952-07-16 12:00:00     0  4040000   5238000 1952-04-01
# ...                     ...   ...      ...       ...        ...
# 5433745 2020-07-16 12:00:00     1  4736000   6102000 2020-10-31
# 5433746 2020-07-16 12:00:00     1  4736000   6106000 2020-10-31
# 5433747 2020-07-16 12:00:00     1  4736000   6110000 2020-10-31
# 5433748 2020-07-16 12:00:00     1  4736000   6114000 2020-10-31
# 5433749 2020-07-16 12:00:00     1  4736000   6118000 2020-10-31
#
#          droughtmagnitude   latitude  longitude
# 0                     NaN   5.952251  46.976737
# 1                     NaN   5.948199  47.012517
# 2                     NaN   5.944138  47.048297
# 3                     NaN   5.940070  47.084076
# 4                     NaN   5.935994  47.119854
# ...                   ...        ...        ...
# 5433745               NaN  15.686301  54.990928
# 5433746               NaN  15.689596  55.026785
# 5433747               NaN  15.692898  55.062641
# 5433748               NaN  15.696208  55.098498
# 5433749               NaN  15.699525  55.134353
#
# [5433750 rows x 8 columns]

# %%
# Drop easting and northing before transformation into csv
df=df.drop(columns=['easting', 'northing'])

# %%
df.head

# %%
# transform into csv
df.to_csv('253177_Duerremagnitude_Gesamtboden_1952-2020_Apr-Okt.csv', index=False)

# %%
# create csv file
from IPython.display import FileLink
FileLink('253177_Duerremagnitude_Gesamtboden_1952-2020_Apr-Okt.csv')
