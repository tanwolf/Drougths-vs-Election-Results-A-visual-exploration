# %% [markdown]
# # Wildfires USA

# %% [markdown]
# #  WFIGS - Wildland Fire Locations Full History
#
# https://services3.arcgis.com/T4QMspbfLg3qTGWY/arcgis/rest/services/Fire_History_Locations_Public/FeatureServer/0

# %%
import pandas as pd

# %%
df_wildfires_usa = pd.read_csv('Data/WFIGS_-_Wildland_Fire_Locations_Full_History.csv')
# Out:
# C:\Users\Tanja\AppData\Local\Temp\ipykernel_10660\3811356723.py:1: DtypeWarning: Columns (13,14,32,61,64,77,94,95) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_wildfires_usa = pd.read_csv('Data/WFIGS_-_Wildland_Fire_Locations_Full_History.csv')

# %%
df_wildfires_usa.head(3)
# Out:
#             X          Y  OBJECTID ABCDMisc ADSPermissionState  \
# 0 -104.457511  45.785037         1      NaN          CERTIFIED
# 1 -118.180712  33.808985         2      NaN            DEFAULT
# 2 -114.835414  48.073946         3      NaN            DEFAULT
#
#    CalculatedAcres     ContainmentDateTime         ControlDateTime  \
# 0            50.64  2020/08/06 23:13:07+00  2020/08/06 23:13:24+00
# 1              NaN                     NaN                     NaN
# 2              NaN  2017/10/18 00:30:00+00  2017/10/18 00:35:00+00
#
#    DailyAcres  DiscoveryAcres  ... IsDispatchComplete  \
# 0        50.6            20.0  ...                  0
# 1         NaN             0.1  ...                  0
# 2        50.0            50.0  ...                  0
#
#    OrganizationalAssessment  StrategicDecisionPublishDate  \
# 0                       NaN                           NaN
# 1                       NaN                           NaN
# ...

# %%
df_wildfires_usa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 232079 entries, 0 to 232078
# Data columns (total 96 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   X                                232079 non-null  float64
#  1   Y                                232079 non-null  float64
#  2   OBJECTID                         232079 non-null  int64
#  3   ABCDMisc                         11540 non-null   object
#  4   ADSPermissionState               232079 non-null  object
#  5   CalculatedAcres                  5140 non-null    float64
#  6   ContainmentDateTime              139608 non-null  object
#  7   ControlDateTime                  126478 non-null  object
#  8   DailyAcres                       160153 non-null  float64
#  9   DiscoveryAcres                   169638 non-null  float64
#  10  DispatchCenterID                 194701 non-null  object
# ...

# %%
df_wildfires_usa_selected_columns = df_wildfires_usa[['CreatedOnDateTime_dt', 'DailyAcres', 'DiscoveryAcres', 'FireCause', 'InitialLatitude', 'InitialLongitude', 'LocalIncidentIdentifier', 'POOCounty', 'POOFips', 'POOState', 'UniqueFireIdentifier']].copy()

# %%
df_wildfires_usa_selected_columns.head(10)
# Out:
#      CreatedOnDateTime_dt  DailyAcres  DiscoveryAcres FireCause  \
# 0  2020/08/06 19:50:29+00        50.6            20.0     Human
# 1  2020/02/28 20:52:36+00         NaN             0.1   Unknown
# 2  2017/10/18 13:46:40+00        50.0            50.0     Human
# 3  2019/07/01 20:10:12+00         NaN             NaN       NaN
# 4  2016/06/20 22:39:02+00         NaN             NaN       NaN
# 5  2020/11/23 21:51:09+00         1.0             1.0     Human
# 6  2019/10/27 00:14:29+00       170.0             0.1   Unknown
# 7  2020/08/27 17:17:17+00         0.1             0.1   Natural
# 8  2020/08/16 19:34:28+00         0.1             NaN     Human
# 9  2015/06/09 04:22:58+00         NaN             0.1     Human
#
#    InitialLatitude  InitialLongitude LocalIncidentIdentifier      POOCounty  \
# 0         45.78496        -104.49580                  000224         Carter
# 1         33.80898        -118.18070                  066100    Los Angeles
# ...

# %%
df_wildfires_usa_selected_columns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 232079 entries, 0 to 232078
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   CreatedOnDateTime_dt     232079 non-null  object
#  1   DailyAcres               160153 non-null  float64
#  2   DiscoveryAcres           169638 non-null  float64
#  3   FireCause                203307 non-null  object
#  4   InitialLatitude          168650 non-null  float64
#  5   InitialLongitude         168650 non-null  float64
#  6   LocalIncidentIdentifier  232079 non-null  object
#  7   POOCounty                231918 non-null  object
#  8   POOFips                  231911 non-null  object
#  9   POOState                 232079 non-null  object
#  10  UniqueFireIdentifier     232079 non-null  object
# dtypes: float64(4), object(7)
# memory usage: 19.5+ MB

# %%
df_wildfires_usa_selected_columns.CreatedOnDateTime_dt = pd.to_datetime(df_wildfires_usa_selected_columns['CreatedOnDateTime_dt'], infer_datetime_format=True)

# %%
df_wildfires_usa_selected_columns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 232079 entries, 0 to 232078
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   CreatedOnDateTime_dt     232079 non-null  datetime64[ns, UTC]
#  1   DailyAcres               160153 non-null  float64
#  2   DiscoveryAcres           169638 non-null  float64
#  3   FireCause                203307 non-null  object
#  4   InitialLatitude          168650 non-null  float64
#  5   InitialLongitude         168650 non-null  float64
#  6   LocalIncidentIdentifier  232079 non-null  object
#  7   POOCounty                231918 non-null  object
#  8   POOFips                  231911 non-null  object
#  9   POOState                 232079 non-null  object
#  10  UniqueFireIdentifier     232079 non-null  object
# dtypes: datetime64[ns, UTC](1), float64(4), object(6)
# memory usage: 19.5+ MB

# %%
df_wildfires_usa_selected_columns.sort_values(by='CreatedOnDateTime_dt', ascending=True)
# Out:
#             CreatedOnDateTime_dt  DailyAcres  DiscoveryAcres     FireCause  \
# 104312 2014-05-21 04:09:45+00:00        0.10            0.10         Human
# 101859 2014-05-21 04:10:04+00:00        0.70            0.10       Unknown
# 136388 2014-05-21 04:10:06+00:00        0.10            0.10         Human
# 44900  2014-05-21 04:10:07+00:00        0.10            0.10         Human
# 2554   2014-05-21 04:10:07+00:00        1.00            0.10         Human
# ...                          ...         ...             ...           ...
# 232074 2022-08-02 13:08:53+00:00        0.10            0.10  Undetermined
# 232075 2022-08-02 13:29:12+00:00        0.01            0.01  Undetermined
# 232076 2022-08-02 13:35:55+00:00        7.40            0.10         Human
# 232077 2022-08-02 13:38:19+00:00        0.10            0.10  Undetermined
# 232078 2022-08-02 13:45:03+00:00        0.10            0.10  Undetermined
#
#         InitialLatitude  InitialLongitude LocalIncidentIdentifier  \
# ...

# %% [markdown]
# Exploration result: Data dates back until 2014. Year 2000 would be preferable.
